# %% [markdown]
# ### **Introducción a Análisis Descriptivo Exploratorio (EDA)**

# %% [markdown]
# #### 1. Importación Librerías

# %%
#!pip install pandas
##Librería para manipulación de datos
import pandas as pd
##Librerías Análisis Matemático
import numpy as np

# %% [markdown]
# #### 2. Importación Data

# %%
##Importación tradicional de la data - Funciones
nombreArchivo ='data.csv'

datos = pd.read_csv('./Dataset/'+nombreArchivo)

datos.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
##Mismo procedimiento pero con Funciones
def importData(ruta, nomArchivo):
    datos = pd.read_csv(ruta+nomArchivo)
    return datos

calorias = importData('./Dataset/','data.csv')

calorias.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
##Importar dato de tipo JS
def importDataJson(ruta, nomArchivo):
    datos = pd.read_json(ruta+nomArchivo)
    return datos

caloriaDos = importDataJson('./Dataset/','data.js')

caloriaDos.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
##Importación de datos desde la nube
def importNube(url, sep):
    df = pd.read_csv(url, sep=sep)
    return df

cancer = importNube('https://query.data.world/s/lzwxkoqy7xwsuf255pzz2py7usrt6u',';')

cancer.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
##Cargamos libros de excel - especificamente una hoja
def importDatoExcel(ruta, nomArchivo, coluno, coldos):
    df = pd.read_excel(ruta+nomArchivo)
    dfdos = pd.DataFrame(df, columns=[coluno, coldos])
    return dfdos

productos = importDatoExcel('./Dataset/', 'Productos.xlsx', 'producto','precio')

productos
# Out:
#         producto   precio
# 0     computador  1200000
# 1         nevera  3200000
# 2             tv  5000000
# 3  equipo sonido   560000

# %%
##Importar multiples hojas de excel, misma estructura
def importDataMul(url, nomarchivo):
    df = pd.concat(pd.read_excel(url+nomarchivo, sheet_name=None),ignore_index=True)
    return df

dataConc = importDataMul('https://github.com/chris1610/pbpython/raw/master/data/','2018_Sales_Total_Tabs.xlsx')

dataConc.head()

#dataConc.info()
# Out:
#    account number             name       sku  quantity  unit price  ext price  \
# 0          412290    Jerde-Hilpert  S2-77896        43       76.66    3296.38
# 1          383080         Will LLC  S1-93683        28       90.86    2544.08
# 2          729833        Koepp Ltd  S1-30248        13       44.84     582.92
# 3          424914    White-Trantow  S2-82423        38       50.93    1935.34
# 4          672390  Kuhn-Gusikowski  S1-50961        34       48.20    1638.80
#
#                  date
# 0 2018-03-04 23:10:28
# 1 2018-03-05 05:11:49
# 2 2018-03-05 17:33:52
# 3 2018-03-05 21:40:10
# 4 2018-03-06 11:59:00

# %% [markdown]
# ### 2. Extracción de la data

# %%
dataConc.to_csv('dataUnida.csv', sep=';')

##Quita encabezados
dataConc.to_csv('dataUnida.csv', sep=';', header=False)

##Quitar la numeración de filas
dataConc.to_csv('dataUnida.csv', sep=';',index= False)

##Tildes o letra ñ o caracter especial
dataConc.to_csv('dataUnida.csv', sep=';', index=False, encoding='windows-1252')

##Otros formatos
dataConc.to_json('data.json')

##Extraer ciertas columnas.
dataConc.to_csv('dataUnida.csv', sep=';', index=False, encoding='windows-1252', columns=['sku','quantity'])

##Copias del dataframe
datanueva = dataConc

# %% [markdown]
# ### 3. Operaciones Dataframes

# %%
dataConc.shape
# Out:
# (299, 7)

# %%
dataConc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   account number  299 non-null    int64
#  1   name            299 non-null    object
#  2   sku             299 non-null    object
#  3   quantity        299 non-null    int64
#  4   unit price      299 non-null    float64
#  5   ext price       299 non-null    float64
#  6   date            299 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(2), object(2)
# memory usage: 16.5+ KB

# %%
columnas = dataConc.columns
columnas
# Out:
# Index(['account number', 'name', 'sku', 'quantity', 'unit price', 'ext price',
#        'date'],
#       dtype='object')

# %%
dataConc.dtypes
# Out:
# account number             int64
# name                      object
# sku                       object
# quantity                   int64
# unit price               float64
# ext price                float64
# date              datetime64[ns]
# dtype: object

# %%
dataConc.count()
# Out:
# account number    299
# name              299
# sku               299
# quantity          299
# unit price        299
# ext price         299
# date              299
# dtype: int64

# %%
dataConc.describe().T
# Out:
#                 count           mean            std        min        25%  \
# account number  299.0  476205.913043  220970.566482  141962.00  257198.00
# quantity        299.0      24.187291      14.874138      -1.00      11.00
# unit price      299.0      56.619933      27.049789      10.21      32.92
# ext price       299.0    1383.145886    1129.304890     -97.16     416.85
#
#                       50%        75%        max
# account number  424914.00  714466.00  786968.00
# quantity            24.00      38.00      49.00
# unit price          58.28      80.54      99.73
# ext price         1116.28    2133.92    4543.96

# %%
dataConc.nunique()
# Out:
# account number     20
# name               20
# sku                30
# quantity           50
# unit price        296
# ext price         298
# date              299
# dtype: int64

# %%
dataConc['sku'].value_counts()
# Out:
# S1-93683    20
# S1-82801    15
# S1-30248    13
# B1-53636    13
# B1-53102    13
# S2-82423    12
# S2-10342    12
# S2-83881    12
# S2-23246    12
# B1-38851    12
# S2-77896    11
# S2-16558    11
# B1-05914    11
# B1-20000    11
# S1-27722    10
# S1-47412    10
# B1-33087     9
# S1-06532     9
# S2-34077     9
# B1-33364     8
# B1-65551     8
# S2-78676     8
# B1-50809     7
# B1-86481     7
# S1-50961     7
# B1-69924     6
# S1-65481     6
# B1-04202     6
# S2-11481     6
# S2-00301     5
# Name: sku, dtype: int64

# %%
productos['producto'].value_counts()
# Out:
# computador       1
# nevera           1
# tv               1
# equipo sonido    1
# Name: producto, dtype: int64

# %%
prod = productos.rename(columns={'producto':'NomProducto'})

prod
# Out:
#      NomProducto   precio
# 0     computador  1200000
# 1         nevera  3200000
# 2             tv  5000000
# 3  equipo sonido   560000

# %%
datanu = dataConc.drop(columns=['sku','name'])

datanu
# Out:
#      account number  quantity  unit price  ext price                date
# 0            412290        43       76.66    3296.38 2018-03-04 23:10:28
# 1            383080        28       90.86    2544.08 2018-03-05 05:11:49
# 2            729833        13       44.84     582.92 2018-03-05 17:33:52
# 3            424914        38       50.93    1935.34 2018-03-05 21:40:10
# 4            672390        34       48.20    1638.80 2018-03-06 11:59:00
# ..              ...       ...         ...        ...                 ...
# 294          239344        41       78.90    3234.90 2018-03-04 01:06:20
# 295          218895        38       89.02    3382.76 2018-03-04 01:17:11
# 296          642753        40       56.85    2274.00 2018-03-04 01:49:22
# 297          737550        12       63.60     763.20 2018-03-04 15:26:20
